# %%
"""eod_sale — the thin pipeline. All it does is wire the three steps to the base."""
from ssv_data.runtime.pipeline import MedallionPipeline
# Out:
# StatementMeta(, 25e07123-2018-46fb-8664-6668444246d0, 5, Finished, Available, Finished, False)

# %%
# %run bronze.py
# Out:
# StatementMeta(, 25e07123-2018-46fb-8664-6668444246d0, 9, Finished, Available, Finished, True)

# %%
# %run silver.py
# Out:
# StatementMeta(, 25e07123-2018-46fb-8664-6668444246d0, 10, Finished, Available, Finished, False)
# UsageError: Line magic function `%` not found.

# %%
# %run gold.py
# Out:
# StatementMeta(, 25e07123-2018-46fb-8664-6668444246d0, -1, Cancelled, , Cancelled, True)

# %%
class EodSalePipeline(MedallionPipeline):
    name = "eod_sale_product"
 
    def ingest(self, ctx):
        # bronze_ingest(ctx)
        ...
    
    def build_silver(self, ctx):
        silver_build(ctx)
 
    def build_gold(self, ctx):
        gold_build(ctx)
# Out:
# StatementMeta(, 25e07123-2018-46fb-8664-6668444246d0, -1, Cancelled, , Cancelled, True)
