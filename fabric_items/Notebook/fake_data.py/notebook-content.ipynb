# %%
# %pip install pymongo
# Out:
# StatementMeta(, 13e66565-e929-4611-ba06-0c49e349dd8e, 9, Finished, Available, Finished, True)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 32.5 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 63.1 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
# %run simulators.py
# Out:
# StatementMeta(, 13e66565-e929-4611-ba06-0c49e349dd8e, 11, Finished, Available, Finished, True)

# %%
def get_secret(name): return spark.conf.get("spark.ssv.secret." + name.replace("-", "_"))

# Mongo: đẩy 30 ngày lên Atlas
mongo_load_atlas(get_secret("mongo-conn"), start="2025-11-01", end="2025-11-30")

# PG: xuất seed SQL 30 ngày (rồi psql nạp), hoặc ghi thẳng bronze để test nhanh:
write_postgres_seed_sql("/lakehouse/default/Files/postgres_seed.sql",
                        start="2025-11-01", end="2025-11-30")
# Out:
# StatementMeta(, 13e66565-e929-4611-ba06-0c49e349dd8e, 12, Finished, Available, Finished, False)
# atlas report.sale_bill: inserted 6769
# atlas report.sale_return_bill: inserted 325
# atlas delivery_order.partner_store: inserted 3
# wrote /lakehouse/default/Files/postgres_seed.sql (2025-11-01..2025-11-30 (30 days))
